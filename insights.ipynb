# %% [markdown]
# # LADD Insights
#
#
# - Engineering (Teacher - Student dynamics)
# - - DDP instead of FSDP (6B param backbone optimizer state bottleneck for training full model distillation 78G footprint at BS=1)
# - - solution: reduced depth student, same architecture, initialized from corresponding layers in teacher (linear interpolation map)
# - - teacher [0, 1, .... 29] -> student[0, 5, 10,...29]
#
# ![image.png](attachment:image.png)
#
#
# - Data (Potential for out of distribution)
# - - JourneyDB synthetic
#
# - Distillation Objective
# - - trajectory rollout schedule annealing
# - - Teacher Rollout
# - - Discriminator Head choices: convnet final, transformer for activations
# - - loss weighting
# - - simplest implementation
#
#
# - Observability and Evaluation
# - - WANDB hooks for loss curves and metrics
# - - Inference samples at same NFE between student and teacher
# - - Student sweep across multiple checkpoints throughout training
# - - Eval set of prompts
# - - if time permits average CLIP score (Student vs Teacher) for given set of prompts.
#
# - Compute and Time

# %% [markdown]
# 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
