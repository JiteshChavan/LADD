# %% [markdown]
# # Hugging face:
# pip install -U huggingface_hub
#
# hf auth login
#
# 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
#
# hf download Tongyi-MAI/Z-Image --include "tokenizer/*" "text_encoder/*" "vae/*" "transformer/*" "scheduler/*" "model_index.json" --local-dir /root/Grace/VideoX-Fun/models/Z-Image
# - count files in current folder
# ls -1 . | wc -l

# %% [markdown]
# # Downlaod data
# cd data
#
# bash get_jdb.sh directory size numproc

# %% [markdown]
# I first validated the end-to-end pipeline (tokenization → text encoder → VAE encoding) on a single sample to ensure correctness before scaling to dataset preprocessing.

# %% [markdown]
# text embedding 512x2560 (including padding mask)
# vae latent space for 512x512 (16, 64, 64)

# %% [markdown]
# I chose 512×512 to prioritize a stable, explainable end-to-end distillation pipeline within the time box. It reduces memory and throughput risk, keeps the 20k-step run practical, and is sufficient to demonstrate the LADD integration clearly.

# %%
Early exit on teacher model for latent matching

# %% [markdown]
# - pip install mosaicml-streaming
